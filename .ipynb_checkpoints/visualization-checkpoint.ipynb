# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Video

# %%
df = pd.read_csv('./boston.csv')

# %%
plt.scatter(x=df.MEDV, y=df.CRIM)
plt.show()

# %%
Image('./chart-chooser-data-visualization.png')

# %%
#DataFrame visualization
df.plot()

# %%
#LON visualization
df.LON.plot()

# %%
#MEDV and LON, Bar visualization
df[['LON', 'MEDV']].plot.bar()

# %%
#MEDV, LAT, LON, ZN histogram visualization
df[['LON', 'ZN', 'LAT', 'MEDV']].plot.hist()

# %%
#MEDV, LAT, LON, ZN diff histogram visualization
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f669b2a3400>,
# ...
#       dtype=object)
