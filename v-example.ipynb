# %%
# %load_ext watermark
# %watermark
# Out:
# 2019-03-12T21:23:36-04:00
#
# CPython 3.6.8
# IPython 6.2.1
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-46-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
#import library
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns
import altair as alt

# %%
#load datasets
df = pd.read_csv('heart.csv')
df.head()

#edad
#sexo
#tipo del dolor de pecho
#presión arterial en reposo
#Colesterol sérico en mg / dl
#(azúcar en la sangre en ayunas> 120 mg / dl) (1 = verdadero; 0 = falso)
#Resultados electrocardiográficos en reposo.
#ritmo cardíaco máximo alcanzado
#angina inducida por el ejercicio (1 = sí; 0 = no)
#Depresión ST inducida por el ejercicio en relación con el descanso.
#La pendiente del segmento pico del ejercicio ST.
#número de vasos principales (0-3) coloreados por fluoroscopia
#3 = normal; 6 = defecto fijo; 7 = defecto reversible
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#data analizis
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#data visulization for analizis
# %matplotlib notebook
sns.heatmap(df.corr())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.pairplot(df)
# Out:
# <img src="data:image/png;base64,..." width="3500">

# %%
sns.lmplot(x="age", y="oldpeak", data=df)
# Out:
# <img src="data:image/png;base64,..." width="500">
# /home/eddydecena/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
alt.renderers.enable('notebook')
alt.Chart(df).mark_bar().encode(
    x='age',
    y='oldpeak'
).properties(
    width=600,
    height=600
).interactive()

# %%
import bokeh.plotting as bk
from bokeh.palettes import brewer 
colors = brewer['BuPu'][3]

# %%
dfm = pd.read_csv('./misteriosos.csv')
dfm_index = dfm.set_index('dataset')

# %%
# %matplotlib notebook
fig = bk.Figure(plot_width=600, plot_height=600, title="Datasets Misterioso!!")
fig.scatter(dfm_index.loc['clase1'].x, dfm_index.loc['clase1'].y, color=colors[0], legend='clase1')
fig.scatter(dfm_index.loc['clase2'].x, dfm_index.loc['clase2'].y, color=colors[1], legend='clase2')
bk.show(fig)
#fig.scatter(dfm_index.loc['clase1'].x, dfm_index.loc['clase1'].y, color=colors[0], legend='clase1')
